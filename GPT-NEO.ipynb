# %%
#@title Automatically setup GPT-NEO and initialize models

# !pip install torch torchvision torchaudio transformers
from transformers import GPTNeoForCausalLM, GPT2Tokenizer
import torch
model_name = "EleutherAI/gpt-neo-1.3B"
model = GPTNeoForCausalLM.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
# Out:
# ...
#      |████████████████████████████████| 3.8 MB 12.0 MB/s
# ...
#      |████████████████████████████████| 895 kB 36.9 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 40.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 30.5 MB/s
# ...
#      |████████████████████████████████| 67 kB 5.2 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
# Downloading:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/779k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/200 [00:00<?, ?B/s]

# %%
#@title Move model to CUDA (only trigger after ram readings lower)
# %%capture
use_cuda = True
model.to("cuda:0")

# %%
#@title Set values for the Transformer and generate output:
prompt = "My favorite animal is" #@param {type:"string"}
output_length = 300 #@param {type:"slider", min:200, max:2000, step:50}
temperature = 0.8 #@param {type:"slider", min:0, max:1, step:0.05}
# generate output
input_ids = tokenizer(prompt, return_tensors="pt").input_ids
if use_cuda:
    input_ids = input_ids.cuda()
gen_tokens = model.generate(input_ids, do_sample=True, tmp=temperature, max_length=output_length)
gen_text = tokenizer.batch_decode(gen_tokens)[0]
print("--- \n \n" + gen_text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ---
#
# My favorite animal is the black bear. I just saw a black bear cub, almost two years old, and I’m just so amazed. His mother is at about five and one half feet… It’s huge. And his father is kind of old, too—but he’ll just grow all bigger! This guy makes you feel tiny in that tiny world. And these little guys are absolutely adorable! You really feel like you want to be them. I have a lot of black bears on my property… They’re just so interesting, and just so curious. They know where all my food is. When I cook meat, they know which bones go in the bowl, and what’s in the stew. They’re like little cogs in the machine—and all of a sudden, they’re making all these noises like they’re really hungry. And they have super high pitched, squeaky sounds, like tiny hammers or something. It’s so cute, but it’s so fun, too.
#
# ...
